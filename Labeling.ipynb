# %% [markdown]
# ### CICModbus2023 Flow labeling

# %%
import os
import pandas as pd
import numpy as np
import os
import re
from bisect import bisect_left, bisect_right
import json 

class ModbusDataset():
    """
    A class to organize and manage the CICModbus 2023 directories with simple hierarchical structure
    and metadata.
    """
    def __init__(self, _root_dir = "./ModbusDataset"):
        self.root_dir = _root_dir
        datasets_dir = self.find_csv_in_folder(root_dir,"output")
        benign_datasets_dir = self.find_csv_in_list(datasets_dir,"benign")
        attack_dataset_dir = self.find_csv_in_list(datasets_dir,"attack")
        ext_attack_dataset_dir = self.find_csv_in_list(attack_dataset_dir,"external")
        comp_ied_attack_dataset_dir = self.find_csv_in_list(attack_dataset_dir,"compromised-ied")
        comp_scada_attack_dataset_dir =self.find_csv_in_list(attack_dataset_dir,"compromised-scada")
        attack_logs_dir = self.find_csv_in_folder(root_dir,"attack logs")
        attack_logs_dir.extend(self.find_csv_in_folder(root_dir,"attacker logs"))
        ## Corrupted TimeStamp (more detail in ./ModbusDataset/Readme.md)
        attack_logs_dir.remove("./ModbusDataset/attack/compromised-scada/attack logs/03-21-2023/03-21-2023-1-original.csv")
        ext_attack_log_dir = self.find_csv_in_list(attack_logs_dir,"external")
        comp_ied_attack_log_dir = self.find_csv_in_list(attack_logs_dir,"compromised-ied")
        comp_scada_attack_log_dir =self.find_csv_in_list(attack_logs_dir,"compromised-scada")


        self.dataset ={
            "metadata":{
                "total_dataset_num":len(datasets_dir),"benign_dataset_num":len(benign_datasets_dir),"attack_dataset_num":{
                "total_num":len(attack_dataset_dir),
                "external_num":len(ext_attack_dataset_dir),
                "compromised-ied_num":len(comp_ied_attack_dataset_dir),
                "compromised-scada_num":len(comp_scada_attack_dataset_dir),
                },"attack_logs_num":{
                    "total_num":len(attack_logs_dir),
                    "external_num":(ext_attack_log_dir),
                    "compromised-ied_num":len(comp_ied_attack_log_dir),
                    "compromised-scada_num":len(comp_scada_attack_log_dir),
                }
            },
            "benign_dataset_dir":benign_datasets_dir,
            "attack_dataset_dir":{"total":attack_dataset_dir,
                                  "external":ext_attack_dataset_dir,
                                  "compromised-ied":comp_ied_attack_dataset_dir,
                                  "compromised-scada":comp_scada_attack_dataset_dir}
            ,
            "attack_log_dir":{"total":attack_logs_dir,
                            "external":ext_attack_log_dir,
                            "compromised-ied":comp_ied_attack_log_dir,
                            "compromised-scada":comp_scada_attack_log_dir}}
        
    def find_csv_in_folder(self,_start_path,_folder_name):
        csv_files = []
        for root, _, files in os.walk(_start_path):
            if _folder_name in root.split(os.sep) :
                csv_files.extend([os.path.join(root, f) for f in files if f.endswith('.csv')])
        return csv_files

    def find_csv_in_list(self,_datasets_dir,_folder_name):
        return  [ds for ds in _datasets_dir  if ds.find(_folder_name)!=(-1)]
    
    def summary_print(self):
        print(json.dumps(modbus.dataset, indent = 4))

    def print_csv(datasets_dir_list,replace_dir):
        for i,dataset in enumerate(datasets_dir_list) :
            print(i+1,dataset.replace(replace_dir,""))

print("pandas current version ",pd.__version__)
print("numpy current version ",np.__version__)
root_dir = "./ModbusDataset"
modbus = ModbusDataset(root_dir)
modbus.summary_print()
# Out:
# pandas current version  2.2.0
# numpy current version  1.26.3
# {
#     "metadata": {
#         "total_dataset_num": 170,
#         "benign_dataset_num": 62,
#         "attack_dataset_num": {
#             "total_num": 108,
#             "external_num": 8,
#             "compromised-ied_num": 43,
#             "compromised-scada_num": 57
#         },
#         "attack_logs_num": {
#             "total_num": 34,
#             "external_num": [
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/02-01-2023/02-01-2023-1.csv",
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/12-29-2022/12-29-2022-1.csv",
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/01-17-2023/01-17-2023-1.csv",
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/01-02-2023/01-02-2023-1.csv",
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/12-30-2022/12-30-2022-1.csv",
#                 "./ModbusDataset/attack/external/external-attacker/attacker logs/01-01-2023/01-01-2023-1.csv"
#             ],
#             "compromised-ied_num": 7,
#             "compromised-scada_num": 21
#         }
#     },
#     "benign_dataset_dir": [
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-18_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-22_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-30_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-19_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-32_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-25_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-15_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-31_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-24_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-14_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-23_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-20_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-21_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-17_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-16_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-26_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-28_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-27_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-29_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-10_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-5_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-6_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-8_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-11_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-4_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-7_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-9_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-4_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-9_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-5_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-10_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-7_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-6_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-8_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-27_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-23_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-14_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-16_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-18_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-15_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-25_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-28_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-29_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-22_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-17_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-19_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-13_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-21_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-26_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-30_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-20_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-24_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-31_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/central-agent/central-agent-network-capture/output/veth460b141-normal_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-9_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-6_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-7_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-5_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-11_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-10_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-4_fix_ord.pcap_Flow.csv",
#         "./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-8_fix_ord.pcap_Flow.csv"
#     ],
#     "attack_dataset_dir": {
#         "total": [
#             "./ModbusDataset/attack/external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-17_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-19_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-18_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-17_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv"
#         ],
#         "external": [
#             "./ModbusDataset/attack/external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv"
#         ],
#         "compromised-ied": [
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-19_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-18_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-17_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv"
#         ],
#         "compromised-scada": [
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-15_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-16_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-9_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-10_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-6_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-14_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-8_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-13_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-12_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-0_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-3_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-7_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-4_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-5_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-17_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-11_fix_ord.pcap_Flow.csv",
#             "./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-2_fix_ord.pcap_Flow.csv"
#         ]
#     },
#     "attack_log_dir": {
#         "total": [
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-18-2023/03-18-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-20-2023/03-20-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-22-2023/03-22-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-17-2023/03-17-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-17-2023/03-17-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-13-2023/03-13-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-13-2023/03-13-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-19-2023/03-19-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-21-2023/03-21-2023-1-fixed.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-3.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-26-2023/03-26-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-29-2023/03-29-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-27-2023/03-27-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-23-2023/03-23-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-25-2023/03-25-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-24-2023/03-24-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-28-2023/03-28-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/02-01-2023/02-01-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-29-2022/12-29-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-17-2023/01-17-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-02-2023/01-02-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-30-2022/12-30-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-01-2023/01-01-2023-1.csv"
#         ],
#         "external": [
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/02-01-2023/02-01-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-29-2022/12-29-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-17-2023/01-17-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-02-2023/01-02-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-30-2022/12-30-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-01-2023/01-01-2023-1.csv"
#         ],
#         "compromised-ied": [
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-26-2023/03-26-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-29-2023/03-29-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-27-2023/03-27-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-23-2023/03-23-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-25-2023/03-25-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-24-2023/03-24-2023-1.csv",
#             "./ModbusDataset/attack/compromised-ied/attack logs/03-28-2023/03-28-2023-1.csv"
#         ],
#         "compromised-scada": [
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-18-2023/03-18-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-16-2023/03-16-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-20-2023/03-20-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-22-2023/03-22-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-14-2023/03-14-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-3.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-15-2023/03-15-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-17-2023/03-17-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-17-2023/03-17-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-13-2023/03-13-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-13-2023/03-13-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-19-2023/03-19-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-21-2023/03-21-2023-1-fixed.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-1.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-2.csv",
#             "./ModbusDataset/attack/compromised-scada/attack logs/03-12-2023/03-12-2023-3.csv"
#         ]
#     }
# }
# /tmp/ipykernel_45748/4151354823.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
print("list of benign csv dataset directories under ./ModbusDataset/benign/*")
ModbusDataset.print_csv(modbus.dataset["benign_dataset_dir"],"./ModbusDataset/benign/")
print("list of attack csv dataset directories under ./ModbusDataset/attack/*")
ModbusDataset.print_csv(modbus.dataset["attack_dataset_dir"]["total"],"./ModbusDataset/attack/")
# Out:
# list of benign csv dataset directories under ./ModbusDataset/benign/*
# 1 network-wide-pcap-capture/network-wide/output/network-wide-normal-18_fix_ord.pcap_Flow.csv
# 2 network-wide-pcap-capture/network-wide/output/network-wide-normal-22_fix_ord.pcap_Flow.csv
# 3 network-wide-pcap-capture/network-wide/output/network-wide-normal-30_fix_ord.pcap_Flow.csv
# 4 network-wide-pcap-capture/network-wide/output/network-wide-normal-19_fix_ord.pcap_Flow.csv
# 5 network-wide-pcap-capture/network-wide/output/network-wide-normal-32_fix_ord.pcap_Flow.csv
# 6 network-wide-pcap-capture/network-wide/output/network-wide-normal-25_fix_ord.pcap_Flow.csv
# 7 network-wide-pcap-capture/network-wide/output/network-wide-normal-15_fix_ord.pcap_Flow.csv
# 8 network-wide-pcap-capture/network-wide/output/network-wide-normal-31_fix_ord.pcap_Flow.csv
# 9 network-wide-pcap-capture/network-wide/output/network-wide-normal-24_fix_ord.pcap_Flow.csv
# 10 network-wide-pcap-capture/network-wide/output/network-wide-normal-14_fix_ord.pcap_Flow.csv
# 11 network-wide-pcap-capture/network-wide/output/network-wide-normal-23_fix_ord.pcap_Flow.csv
# 12 network-wide-pcap-capture/network-wide/output/network-wide-normal-20_fix_ord.pcap_Flow.csv
# 13 network-wide-pcap-capture/network-wide/output/network-wide-normal-21_fix_ord.pcap_Flow.csv
# 14 network-wide-pcap-capture/network-wide/output/network-wide-normal-17_fix_ord.pcap_Flow.csv
# 15 network-wide-pcap-capture/network-wide/output/network-wide-normal-16_fix_ord.pcap_Flow.csv
# 16 network-wide-pcap-capture/network-wide/output/network-wide-normal-26_fix_ord.pcap_Flow.csv
# 17 network-wide-pcap-capture/network-wide/output/network-wide-normal-28_fix_ord.pcap_Flow.csv
# 18 network-wide-pcap-capture/network-wide/output/network-wide-normal-27_fix_ord.pcap_Flow.csv
# 19 network-wide-pcap-capture/network-wide/output/network-wide-normal-29_fix_ord.pcap_Flow.csv
# 20 ied4c/ied4c-network-capture/output/veth8bc3408-normal-10_fix_ord.pcap_Flow.csv
# 21 ied4c/ied4c-network-capture/output/veth8bc3408-normal-5_fix_ord.pcap_Flow.csv
# 22 ied4c/ied4c-network-capture/output/veth8bc3408-normal-6_fix_ord.pcap_Flow.csv
# 23 ied4c/ied4c-network-capture/output/veth8bc3408-normal-8_fix_ord.pcap_Flow.csv
# 24 ied4c/ied4c-network-capture/output/veth8bc3408-normal-11_fix_ord.pcap_Flow.csv
# 25 ied4c/ied4c-network-capture/output/veth8bc3408-normal-4_fix_ord.pcap_Flow.csv
# 26 ied4c/ied4c-network-capture/output/veth8bc3408-normal-7_fix_ord.pcap_Flow.csv
# 27 ied4c/ied4c-network-capture/output/veth8bc3408-normal-9_fix_ord.pcap_Flow.csv
# 28 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-4_fix_ord.pcap_Flow.csv
# 29 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-9_fix_ord.pcap_Flow.csv
# 30 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-5_fix_ord.pcap_Flow.csv
# 31 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-10_fix_ord.pcap_Flow.csv
# 32 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-7_fix_ord.pcap_Flow.csv
# 33 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-6_fix_ord.pcap_Flow.csv
# 34 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-8_fix_ord.pcap_Flow.csv
# 35 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-27_fix_ord.pcap_Flow.csv
# 36 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-23_fix_ord.pcap_Flow.csv
# 37 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-14_fix_ord.pcap_Flow.csv
# 38 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-16_fix_ord.pcap_Flow.csv
# 39 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-18_fix_ord.pcap_Flow.csv
# 40 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-15_fix_ord.pcap_Flow.csv
# 41 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-25_fix_ord.pcap_Flow.csv
# 42 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-28_fix_ord.pcap_Flow.csv
# 43 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-29_fix_ord.pcap_Flow.csv
# 44 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-22_fix_ord.pcap_Flow.csv
# 45 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-17_fix_ord.pcap_Flow.csv
# 46 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-19_fix_ord.pcap_Flow.csv
# 47 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-13_fix_ord.pcap_Flow.csv
# 48 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-21_fix_ord.pcap_Flow.csv
# 49 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-26_fix_ord.pcap_Flow.csv
# 50 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-30_fix_ord.pcap_Flow.csv
# 51 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-20_fix_ord.pcap_Flow.csv
# 52 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-24_fix_ord.pcap_Flow.csv
# 53 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-31_fix_ord.pcap_Flow.csv
# 54 central-agent/central-agent-network-capture/output/veth460b141-normal_fix_ord.pcap_Flow.csv
# 55 ied1a/ied1a-network-capture/output/veth4edc015-normal-9_fix_ord.pcap_Flow.csv
# 56 ied1a/ied1a-network-capture/output/veth4edc015-normal-6_fix_ord.pcap_Flow.csv
# 57 ied1a/ied1a-network-capture/output/veth4edc015-normal-7_fix_ord.pcap_Flow.csv
# 58 ied1a/ied1a-network-capture/output/veth4edc015-normal-5_fix_ord.pcap_Flow.csv
# 59 ied1a/ied1a-network-capture/output/veth4edc015-normal-11_fix_ord.pcap_Flow.csv
# 60 ied1a/ied1a-network-capture/output/veth4edc015-normal-10_fix_ord.pcap_Flow.csv
# 61 ied1a/ied1a-network-capture/output/veth4edc015-normal-4_fix_ord.pcap_Flow.csv
# 62 ied1a/ied1a-network-capture/output/veth4edc015-normal-8_fix_ord.pcap_Flow.csv
# list of attack csv dataset directories under ./ModbusDataset/attack/*
# 1 external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv
# 2 external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv
# 3 external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv
# 4 external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv
# 5 external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv
# 6 external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv
# 7 external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv
# 8 external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv
# 9 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# 10 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# 11 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# 12 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# 13 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# 14 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# 15 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv
# 16 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# 17 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# 18 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv
# 19 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# 20 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# 21 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# 22 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# 23 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv
# 24 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv
# 25 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv
# 26 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv
# 27 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv
# 28 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv
# 29 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv
# 30 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv
# 31 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv
# 32 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-0_fix_ord.pcap_Flow.csv
# 33 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-8_fix_ord.pcap_Flow.csv
# 34 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-11_fix_ord.pcap_Flow.csv
# 35 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-2_fix_ord.pcap_Flow.csv
# 36 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-15_fix_ord.pcap_Flow.csv
# 37 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-7_fix_ord.pcap_Flow.csv
# 38 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-13_fix_ord.pcap_Flow.csv
# 39 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-9_fix_ord.pcap_Flow.csv
# 40 compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# 41 compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# 42 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# 43 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# 44 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# 45 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# 46 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# 47 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv
# 48 compromised-scada/substation-wide-capture/output/substation-15_fix_ord.pcap_Flow.csv
# 49 compromised-scada/substation-wide-capture/output/substation-16_fix_ord.pcap_Flow.csv
# 50 compromised-scada/substation-wide-capture/output/substation-9_fix_ord.pcap_Flow.csv
# 51 compromised-scada/substation-wide-capture/output/substation-10_fix_ord.pcap_Flow.csv
# 52 compromised-scada/substation-wide-capture/output/substation-6_fix_ord.pcap_Flow.csv
# 53 compromised-scada/substation-wide-capture/output/substation-14_fix_ord.pcap_Flow.csv
# 54 compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv
# 55 compromised-scada/substation-wide-capture/output/substation-8_fix_ord.pcap_Flow.csv
# 56 compromised-scada/substation-wide-capture/output/substation-13_fix_ord.pcap_Flow.csv
# 57 compromised-scada/substation-wide-capture/output/substation-12_fix_ord.pcap_Flow.csv
# 58 compromised-scada/substation-wide-capture/output/substation-0_fix_ord.pcap_Flow.csv
# 59 compromised-scada/substation-wide-capture/output/substation-3_fix_ord.pcap_Flow.csv
# 60 compromised-scada/substation-wide-capture/output/substation-7_fix_ord.pcap_Flow.csv
# 61 compromised-scada/substation-wide-capture/output/substation-4_fix_ord.pcap_Flow.csv
# 62 compromised-scada/substation-wide-capture/output/substation-5_fix_ord.pcap_Flow.csv
# 63 compromised-scada/substation-wide-capture/output/substation-17_fix_ord.pcap_Flow.csv
# 64 compromised-scada/substation-wide-capture/output/substation-11_fix_ord.pcap_Flow.csv
# 65 compromised-scada/substation-wide-capture/output/substation-2_fix_ord.pcap_Flow.csv
# 66 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# 67 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# 68 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# 69 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# 70 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# 71 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# 72 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# 73 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# 74 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# 75 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# 76 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# 77 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# 78 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-19_fix_ord.pcap_Flow.csv
# 79 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-12_fix_ord.pcap_Flow.csv
# 80 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-9_fix_ord.pcap_Flow.csv
# 81 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-18_fix_ord.pcap_Flow.csv
# 82 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-13_fix_ord.pcap_Flow.csv
# 83 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-7_fix_ord.pcap_Flow.csv
# 84 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-4_fix_ord.pcap_Flow.csv
# 85 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-14_fix_ord.pcap_Flow.csv
# 86 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-17_fix_ord.pcap_Flow.csv
# 87 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-6_fix_ord.pcap_Flow.csv
# 88 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-11_fix_ord.pcap_Flow.csv
# 89 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-16_fix_ord.pcap_Flow.csv
# 90 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-8_fix_ord.pcap_Flow.csv
# 91 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-3_fix_ord.pcap_Flow.csv
# 92 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv
# 93 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-5_fix_ord.pcap_Flow.csv
# 94 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-2_fix_ord.pcap_Flow.csv
# 95 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-1_fix_ord.pcap_Flow.csv
# 96 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-0_fix_ord.pcap_Flow.csv
# 97 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-10_fix_ord.pcap_Flow.csv
# 98 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# 99 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-4_fix_ord.pcap_Flow.csv
# 100 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# 101 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-3_fix_ord.pcap_Flow.csv
# 102 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-2_fix_ord.pcap_Flow.csv
# 103 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# 104 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# 105 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# 106 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# 107 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# 108 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv

# %% [markdown]
# #### Labeling functions

# %%
# Basic preprocessing before getting started on labelling.
# Deletes rows with "Infinity" and NaNs, converts "Timestamp" to Pandas Datetime, and converts all necessary columns to numeric values
# Int_64 Columns (Attempted-Category) not considered.

print_index = False

def format_csv_for_labelling(df):
    df = df.replace('Infinity', np.nan)
    # Clean the Timestamp strings to always include microseconds (append .0 if missing)
    df['Timestamp'] = pd.to_datetime(
        df['Timestamp'].apply(
            lambda x: x if '.' in x.split()[-1] else f"{x}.0"  # Split into date/time and check time part
        ),
        format='%Y-%m-%d %H:%M:%S.%f'  # Parse with microseconds
    )
    for column in df.columns:
        if column not in ['Flow ID' , 'Timestamp', 'Src IP', 'Dst IP', 'Label','Attack','TransactionID','TargetIP']:
            df[column] = pd.to_numeric(df[column], errors='coerce')
    df.dropna()
    return df.dropna()

def read_csvs_from_path_and_reformat(path):
    df = pd.read_csv(path, encoding='cp1252')

    df = format_csv_for_labelling(df)
    print("labels after pre-processing:\n", df["Label"].value_counts())

    int32_columns = ["Src Port", "Dst Port", "Flow Duration", "Total Fwd Packet", "Total Bwd packets", "Total Length of Fwd Packet", "Total Length of Bwd Packet", "Fwd Packet Length Max",
        "Fwd Packet Length Min", "Bwd Packet Length Max", "Bwd Packet Length Min", "Flow IAT Max", "Flow IAT Min", "Fwd IAT Total", "Fwd IAT Max", "Fwd IAT Min", "Bwd IAT Total",
        "Bwd IAT Max", "Bwd IAT Min", "Fwd PSH Flags", "Bwd PSH Flags", "Fwd URG Flags", "Bwd URG Flags", "Packet Length Min", "Packet Length Max", "FIN Flag Count", "SYN Flag Count", "RST Flag Count", "PSH Flag Count",
        "ACK Flag Count", "URG Flag Count", "CWR Flag Count", "ECE Flag Count", "Subflow Fwd Packets", "Subflow Fwd Bytes",
        "Subflow Bwd Packets", "Subflow Bwd Bytes", "FWD Init Win Bytes", "Bwd Init Win Bytes", "Fwd Act Data Pkts", "Fwd Seg Size Min", "Active Max",
        "Active Min", "Idle Max", "Idle Min"]

    int16_columns = ["Fwd Header Length", "Bwd Header Length", "ICMP Code", "ICMP Type"]

    for column in int32_columns:
        df[column] = df[column].astype('int32')

    for column in int16_columns:
        df[column] = df[column].astype('int16')

    return df


# This function is called when all labelling of malicious flows is completed. Anything that has not yet received a label
# so far is labelled as Benign.
# write dataframe to csv file in ready directory (create if not exist )
def label_rest_as_benign_and_write_csv(df, input_path):
    
    df["Label"]=df["Label"].mask(df["Label"] == "NeedManualLabel", "BENIGN")
    print("label count after labelling:\r\n", df["Label"].value_counts())
    # Construct the ready directory path alongside output
    ready_dir = os.path.join(os.path.dirname(os.path.dirname(input_path)), 'ready')
    os.makedirs(ready_dir, exist_ok=True)
    filename = os.path.basename(input_path)
    name, ext = os.path.splitext(filename)  # Split the extension (name, ".csv")
    cleaned_name = name.replace("_fix_ord.pcap_Flow", "-labeled")
    # Construct full output path
    output_path = os.path.join(ready_dir, f"{cleaned_name}{ext}")  # Append extension
    # Adds line numbers in the first column if print_index is set to true
    if print_index:
        df.reset_index(inplace=True, drop=True)
        df.index += 1
        df.index.name = 'id'
        df.to_csv(output_path)
    else:
        df.to_csv(output_path, index=False)

def sort_df(_df):
    """    
    return sorted dataframe vertically with respect to TimeStamps
    """    
    new_df_sorted = _df.sort_values(by='Timestamp', ascending=True)
    new_df_sorted = new_df_sorted.reset_index(drop=True)
    return new_df_sorted

def merge_datasets(_dataset_dir):
    """
        create dataframes from the directories then return the merged_file  
    """
    # take two columns (attack logs ) or four columns (attacker logs)    
    merged_new_df = format_csv_for_labelling(pd.read_csv(_dataset_dir[0], encoding='cp1252'))
    for _dir in _dataset_dir :
        merged_new_df = pd.concat([format_csv_for_labelling(pd.read_csv(_dir, encoding='cp1252')),merged_new_df],join="inner")
    return merged_new_df

# %% [markdown]
# #### Label All csv files in benign folder as "BENIGN"

# %%
# create new csv files with new labels in ready folder (run it once)
for _dir in modbus.dataset["benign_dataset_dir"]:
    print(_dir)
    # uncomment next line of code if the labeling of the benign dataset does not occured yet !
    #It may take some time !
    # label_rest_as_benign_and_write_csv(read_csvs_from_path_and_reformat(_dir) ,_dir)
# Out:
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-18_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-22_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-30_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-19_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-32_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-25_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-15_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-31_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-24_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-14_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-23_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-20_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-21_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-17_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-16_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-26_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-28_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-27_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/network-wide-pcap-capture/network-wide/output/network-wide-normal-29_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-10_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-5_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-6_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-8_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-11_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-4_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-7_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied4c/ied4c-network-capture/output/veth8bc3408-normal-9_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-4_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-9_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-5_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-10_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-7_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-6_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1b/ied1b-network-capture/output/vethd9e14c0-normal-8_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-27_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-23_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-14_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-16_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-18_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-15_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-25_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-28_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-29_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-22_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-17_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-19_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-13_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-21_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-26_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-30_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-20_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-24_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-31_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/central-agent/central-agent-network-capture/output/veth460b141-normal_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-9_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-6_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-7_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-5_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-11_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-10_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-4_fix_ord.pcap_Flow.csv
# ./ModbusDataset/benign/ied1a/ied1a-network-capture/output/veth4edc015-normal-8_fix_ord.pcap_Flow.csv

# %% [markdown]
# #### Attack Labeling depends on the log Attack , Timestamp columns

# %% [markdown]
# In the log only the completed attacks are reliable. for example
# ```md
# 2023-02-01 13:06:29.2, Brute force or specific coil. Address: 0
# 2023-02-01 13:06:29.201, Brute force or specific - Complete
# ```
# 🟢 It's okay but
# ```md
# 2023-02-01 13:06:29.2, Brute force or specific coil. Address: 0
# ```
# 🔴 It may not be implemented literally at all! !
#
# ❗Unfortunately no exact logging happend in attack/attacker logs
# Complete Timestamp of an attack might be before ending the flow/connection or after that about 2 minutes !!!
# Or the timestamp in the log may be earlier than the timestamp of the .pcap files (SYN).
# Received timestamps of a flow might be different in different nodes make it hard to label automatically.

# %%
def clean_label(label_str):
    """Clean label by removing multiple unwanted substrings/characters"""
    # Remove "Complete" in any casing, commas, hyphens, periods, and everything after a colon
    label_str = re.sub(r'ADDRESS|Complete|or specific|coil|RANGE|range|,|-|\.|:[^:]*$', '', label_str, flags=re.IGNORECASE)
    # Remove any resulting double spaces or trailing hyphens
    label_str = re.sub(r'\s+', ' ', label_str).strip()
    label_str = re.sub(r'\s-\s*$', '', label_str)
    label_str = label_str.upper()
    return label_str

def log_pairs_from_dir(_attack_log_dirs):
    """
    extract start , end , attack label pairs from logs (csv)
    make it ready to be used in label_flows second argument
    """
    # sort attak_df beacuse of overlapped flow durations results in multiple labels 
    # Priority: Earlier flows in attack_df take precedence for labeling when multiple flows contain attack interval
    attack_log_df = sort_df(merge_datasets(_attack_log_dirs))
    #  Find rows in attack_log_df where 'Attack' contains 'Complete'
    # Create a mask for rows where 'Attack' contains 'Complete'
    complete_mask = attack_log_df['Attack'].str.contains('Complete', na=False)
    # Find valid attack pairs and convert to numpy datetime64 upfront
    pairs = []
    for i in attack_log_df.index[complete_mask]:
        if i > 0:
            start = np.datetime64(attack_log_df.at[i-1, 'Timestamp'],'us')
            end = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            label = clean_label(attack_log_df.at[i, 'Attack'])
            pairs.append((start, end, label))


    no_complete_mask = ~(complete_mask | complete_mask.shift(-1, fill_value=False))

    for i in attack_log_df.index[no_complete_mask]:
        if i > 0:
            start = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            end = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            label = clean_label(attack_log_df.at[i, 'Attack'])
            pairs.append((start, end, label))
    return pairs 

def label_flows(_attack_dir,_attack_pairs,src_ip_list=None ,dst_ip_list=None,max_start_timestamp_tolerate= np.timedelta64(100_000, 'us'),max_end_timestamp_tolarate=np.timedelta64(1_000_000, 'us')):
    """
    label flows of the dataset csv file with respect to the logs overlaping timestamp 
    then change the _attack_dir "Label" Column.
    Timestamps are in MICROSECONDS (!) Unix time. Note that the CSV files are in the UTC timezone.
    """

    print("Attack directory ------------------------------",_attack_dir)
        
    attack_df= read_csvs_from_path_and_reformat(_attack_dir)
    attack_df['end_time'] = attack_df['Timestamp'] + pd.to_timedelta(attack_df['Flow Duration'], unit='us')
    attack_df=sort_df(attack_df)

    # print("after----------",(len([ pair[2]  for pair in pairs if "RECON" in pair[2]])))
    # Convert to numpy arrays for vectorized operations
    starts = attack_df['Timestamp'].values.astype('datetime64[us]')
    ends = attack_df['end_time'].values.astype('datetime64[us]')
    labels = attack_df['Label'].values
    orig_indices = attack_df.index.values
    custom_mask = (attack_df['Label'] == "NeedManualLabel").values

    # Precompute mask for unlabeled flows
    custom_mask &= (labels == "NeedManualLabel")
    if src_ip_list is not None:
        custom_mask &= attack_df["Src IP"].isin(src_ip_list).values
    if dst_ip_list is not None:
        custom_mask &= attack_df["Dst IP"].isin(dst_ip_list).values

   # Collect updates to minimize DataFrame operations
    updates = []

    # Process each attack pair
    for start_p, end_p, new_label in _attack_pairs:
        # Find flows that:
        # 1. logging attack Complete within 1 seconds of the flow end_time
        # 2. logging attack start within 0.01 seconds after the flow start
        # 3. Are still unlabeled
        # Find candidate flows using binary search ( sorted attack_df by start timestamp)
        start_left_interval = bisect_left(starts, start_p - max_start_timestamp_tolerate)
        end_right_interval = bisect_right(starts, start_p + max_start_timestamp_tolerate)

        for idx in range(start_left_interval,end_right_interval):
            if custom_mask[idx] and (np.abs(ends[idx] - end_p)<=max_end_timestamp_tolarate ):
                orig_idx = orig_indices[idx]
                updates.append((orig_idx, new_label))
                custom_mask[idx] = False
                break  # Only label the first matching flow

    # Apply all updates at once
    if updates:
        update_indices, update_labels = zip(*updates)
        attack_df.loc[list(update_indices), 'Label'] = list(update_labels)

    # Finalize by labeling remaining flows as benign and writing to CSV
    label_rest_as_benign_and_write_csv(attack_df, _attack_dir)

asdasd

# %% [markdown]
# ##### External Attacks
# 🟢 Attacks from an unknown IP address (185.175.0.7) targeting 185.175.0.4.
#
# ❗Attacks occured in separable detectable interval ( no need for manual )

# %%
# uncomment next lines of code if the labeling of the external attack dataset does not occured yet  !
attack_pairs = log_pairs_from_dir(modbus.dataset["attack_log_dir"]["external"])
for att_dir in modbus.dataset["attack_dataset_dir"]["external"] :
    label_flows(att_dir,attack_pairs,src_ip_list=["185.175.0.7"],
                         max_start_timestamp_tolerate=np.timedelta64(10_000, 'us'),
                         max_end_timestamp_tolarate=np.timedelta64(10_000, 'us'))
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    68931
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BRUTE FORCE    35475
# BENIGN         33456
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    152398
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   151747
# BRUTE FORCE                 613
# RECON                        32
# QUERY FLOODING                2
# LENGTH MANIPULATION           1
# REPLAY                        1
# PAYLOAD INJECTION             1
# STACKED MODBUS FRAMES         1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    59666
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    59666
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    65626
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BRUTE FORCE              36043
# BENIGN                   29545
# RECON                       32
# QUERY FLOODING               2
# LENGTH MANIPULATION          1
# REPLAY                       1
# PAYLOAD INJECTION            1
# STACKED MODBUS FRAMES        1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    36318
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    36318
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    155217
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    155217
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    548
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    548
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    125432
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   89350
# BRUTE FORCE              36044
# RECON                       32
# QUERY FLOODING               2
# LENGTH MANIPULATION          1
# REPLAY                       1
# PAYLOAD INJECTION            1
# STACKED MODBUS FRAMES        1
# Name: count, dtype: int64

# %% [markdown]
# ##### Compromised SCADA Attacks
# 🔴 Attacks from 185.175.0.3 targeting 185.175.0.4 ,185.175.0.5 and 185.175.0.8.Days 12 to 14 in attack logs are missed in pcaps.
#
# ❗❗Attacks not occured in separable detectable interval and need  manually checking

# %%
# uncomment next lines of code if the labeling of the external attack dataset does not occured yet  !

dates = ["03-12-2023", "03-13-2023", "03-14-2023"]
## exclude dates 12,13,14 from attack log dirs
filtered_list = list(filter(lambda x: all(date not in x for date in dates), modbus.dataset["attack_log_dir"]["compromised-scada"]))
attack_pairs = log_pairs_from_dir(filtered_list)

for att_dir in modbus.dataset["attack_dataset_dir"]["compromised-scada"]  :
    label_flows(att_dir,attack_pairs,src_ip_list=["185.175.0.3"],
                dst_ip_list=["185.175.0.4","185.175.0.5","185.175.0.8"],
             max_start_timestamp_tolerate=np.timedelta64(1_000, 'us'),
                         max_end_timestamp_tolarate=np.timedelta64(100_000_000, 'us'))
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    160689
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   160588
# BRUTE FORCE                 100
# STACKED MODBUS FRAMES         1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158034
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   131005
# BRUTE FORCE               26868
# RECON                        48
# PAYLOAD INJECTION            36
# QUERY FLOODING               28
# STACKED MODBUS FRAMES        22
# REPLAY                       20
# LENGTH MANIPULATION           7
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    146703
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   128123
# BRUTE FORCE               18456
# REPLAY                       32
# STACKED MODBUS FRAMES        24
# LENGTH MANIPULATION          20
# QUERY FLOODING               20
# RECON                        16
# PAYLOAD INJECTION            12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150558
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   136814
# BRUTE FORCE               13537
# STACKED MODBUS FRAMES        44
# REPLAY                       41
# RECON                        38
# LENGTH MANIPULATION          32
# PAYLOAD INJECTION            28
# QUERY FLOODING               24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    169162
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   169111
# BRUTE FORCE                  30
# QUERY FLOODING                8
# REPLAY                        5
# RECON                         4
# STACKED MODBUS FRAMES         4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    54280
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN         54278
# BRUTE FORCE        2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    16102
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   12004
# BRUTE FORCE               4065
# REPLAY                      10
# RECON                        8
# PAYLOAD INJECTION            7
# STACKED MODBUS FRAMES        4
# LENGTH MANIPULATION          4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123170
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN         123071
# BRUTE FORCE        99
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    121545
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   88483
# BRUTE FORCE              32803
# REPLAY                      83
# STACKED MODBUS FRAMES       52
# QUERY FLOODING              36
# PAYLOAD INJECTION           32
# LENGTH MANIPULATION         32
# RECON                       24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123174
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    123170
# RECON          4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    120307
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   87543
# BRUTE FORCE              32520
# REPLAY                      49
# RECON                       48
# QUERY FLOODING              47
# PAYLOAD INJECTION           40
# STACKED MODBUS FRAMES       36
# LENGTH MANIPULATION         24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123210
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   95009
# BRUTE FORCE              27978
# LENGTH MANIPULATION         68
# STACKED MODBUS FRAMES       44
# PAYLOAD INJECTION           35
# QUERY FLOODING              31
# REPLAY                      29
# RECON                       16
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    122948
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   85603
# BRUTE FORCE              37129
# STACKED MODBUS FRAMES       51
# REPLAY                      42
# QUERY FLOODING              40
# PAYLOAD INJECTION           31
# RECON                       28
# LENGTH MANIPULATION         24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    122497
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   85782
# BRUTE FORCE              36477
# LENGTH MANIPULATION         55
# REPLAY                      44
# QUERY FLOODING              44
# PAYLOAD INJECTION           38
# RECON                       34
# STACKED MODBUS FRAMES       23
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150177
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   114281
# BRUTE FORCE               35606
# REPLAY                       68
# LENGTH MANIPULATION          58
# QUERY FLOODING               48
# PAYLOAD INJECTION            46
# RECON                        46
# STACKED MODBUS FRAMES        24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    104203
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   100096
# BRUTE FORCE                4070
# RECON                        12
# REPLAY                       10
# PAYLOAD INJECTION             7
# STACKED MODBUS FRAMES         4
# LENGTH MANIPULATION           4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    155022
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   137014
# BRUTE FORCE               17763
# QUERY FLOODING               66
# REPLAY                       52
# PAYLOAD INJECTION            40
# RECON                        36
# LENGTH MANIPULATION          31
# STACKED MODBUS FRAMES        20
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150390
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   126069
# BRUTE FORCE               24195
# STACKED MODBUS FRAMES        43
# REPLAY                       20
# RECON                        19
# LENGTH MANIPULATION          16
# QUERY FLOODING               16
# PAYLOAD INJECTION            12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    157042
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   144548
# BRUTE FORCE               12410
# LENGTH MANIPULATION          32
# STACKED MODBUS FRAMES        16
# PAYLOAD INJECTION            11
# REPLAY                       10
# RECON                         8
# QUERY FLOODING                7
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    148852
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   111596
# BRUTE FORCE               36962
# QUERY FLOODING               69
# REPLAY                       60
# STACKED MODBUS FRAMES        44
# PAYLOAD INJECTION            41
# RECON                        40
# LENGTH MANIPULATION          40
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    146990
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   107720
# BRUTE FORCE               38987
# REPLAY                       75
# RECON                        52
# QUERY FLOODING               50
# STACKED MODBUS FRAMES        41
# LENGTH MANIPULATION          37
# PAYLOAD INJECTION            28
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158355
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN         158264
# BRUTE FORCE        91
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    153491
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                   128499
# BRUTE FORCE               24826
# STACKED MODBUS FRAMES        39
# PAYLOAD INJECTION            39
# REPLAY                       28
# RECON                        28
# LENGTH MANIPULATION          16
# QUERY FLOODING               16
# Name: count, dtype: int64

# %%
modbus.dataset["attack_dataset_dir"]["compromised-scada"].index("./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv")
# Out:
# 45

# %% [markdown]
# ##### Compromised IED Attacks
# - Scada will initiate the connections
# - Attacks from 185.175.0.5 targeting 185.175.0.2 ( reverse direction of the flow).

# %%
for ext_att_dir in modbus.dataset["attack_dataset_dir"]["compromised-ied"] :
    # uncomment next line of code if the labeling of the external attack dataset does not occured yet  !
    #It may take some time !
    if  ("./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv" not in ext_att_dir) :
        continue
    label_flows_from_log(ext_att_dir,modbus.dataset["attack_log_dir"]["compromised-ied"],
                         src_ip_list=["185.175.0.2"],dst_ip_list=["185.175.0.5"])
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    128025
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                         128003
# Length manipulation                 5
# Delay Response Attack               4
# False Data Injection Attack         4
# Baseline Replay                     3
# Starting Query flooding             2
# Frame Stacking                      2
# Query flooding                      1
# Payload Injection                   1
# Name: count, dtype: int64
