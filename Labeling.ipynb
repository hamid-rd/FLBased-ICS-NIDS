# %% [markdown]
# ### CICModbus2023 Flow labeling

# %%
import pandas as pd
import numpy as np
import re
from bisect import bisect_left, bisect_right
import zipfile
from modbus import ModbusDataset
import os 
from collections import Counter

print("pandas current version ",pd.__version__)
print("numpy current version ",np.__version__)
root_dir = "./ModbusDataset"
modbus = ModbusDataset(root_dir,"output")
modbus.summary_print()
# Out:
# /tmp/ipykernel_246718/3552957584.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# pandas current version  2.2.0
# numpy current version  1.26.3
#  The CIC Modbus Dataset contains network (pcap) captures and attack logs from a simulated substation network.
#                 The dataset is categorized into two groups: an attack dataset and a benign dataset
#                 The attack dataset includes network traffic captures that simulate various types of Modbus protocol attacks in a substation environment.
#                 The attacks are reconnaissance, query flooding, loading payloads, delay response, modify length parameters, false data injection, stacking Modbus frames, brute force write and baseline replay.
#                 These attacks are based of some techniques in the MITRE ICS ATT&CK framework.
#                 On the other hand, the benign dataset consists of normal network traffic captures representing legitimate Modbus communication within the substation network.
#                 The purpose of this dataset is to facilitate research, analysis, and development of intrusion detection systems, anomaly detection algorithms and other security mechanisms for substation networks using the Modbus protocol.
#                 https://www.unb.ca/cic/datasets/modbus-2023.html
#                 In my custom PyTorch Dataset class,
#                 I utilize the Enhanced CICflowMeter and the Attack logs correlation to extract and label sequential data flows,
#                 preparing them for batch processing with the DataLoader, which is crucial for AI model training.
#                 https://github.com/hamid-rd/FLBased-ICS-NIDS/tree/main
#
#
# csv files  in the dataset directory founded with the filter:  output
# {
#     "total_dataset_num": 170,
#     "benign_dataset_num": 62,
#     "attack_dataset_num": {
#         "total_num": 108,
#         "external_num": 8,
#         "compromised-ied_num": 43,
#         "compromised-scada_num": 57
#     },
#     "attack_logs_num": {
#         "total_num": 34,
#         "external_num": [
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/02-01-2023/02-01-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-29-2022/12-29-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-17-2023/01-17-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-02-2023/01-02-2023-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/12-30-2022/12-30-2022-1.csv",
#             "./ModbusDataset/attack/external/external-attacker/attacker logs/01-01-2023/01-01-2023-1.csv"
#         ],
#         "compromised-ied_num": 7,
#         "compromised-scada_num": 21
#     }
# }

# %%
print("list of benign csv dataset directories under ./ModbusDataset/benign/*")
ModbusDataset.print_csv(modbus.dataset["benign_dataset_dir"],"./ModbusDataset/benign/")
print("list of attack csv dataset directories under ./ModbusDataset/attack/*")
ModbusDataset.print_csv(modbus.dataset["attack_dataset_dir"]["total"],"./ModbusDataset/attack/")
# Out:
# list of benign csv dataset directories under ./ModbusDataset/benign/*
# 1 network-wide-pcap-capture/network-wide/output/network-wide-normal-18_fix_ord.pcap_Flow.csv
# 2 network-wide-pcap-capture/network-wide/output/network-wide-normal-22_fix_ord.pcap_Flow.csv
# 3 network-wide-pcap-capture/network-wide/output/network-wide-normal-30_fix_ord.pcap_Flow.csv
# 4 network-wide-pcap-capture/network-wide/output/network-wide-normal-19_fix_ord.pcap_Flow.csv
# 5 network-wide-pcap-capture/network-wide/output/network-wide-normal-32_fix_ord.pcap_Flow.csv
# 6 network-wide-pcap-capture/network-wide/output/network-wide-normal-25_fix_ord.pcap_Flow.csv
# 7 network-wide-pcap-capture/network-wide/output/network-wide-normal-15_fix_ord.pcap_Flow.csv
# 8 network-wide-pcap-capture/network-wide/output/network-wide-normal-31_fix_ord.pcap_Flow.csv
# 9 network-wide-pcap-capture/network-wide/output/network-wide-normal-24_fix_ord.pcap_Flow.csv
# 10 network-wide-pcap-capture/network-wide/output/network-wide-normal-14_fix_ord.pcap_Flow.csv
# 11 network-wide-pcap-capture/network-wide/output/network-wide-normal-23_fix_ord.pcap_Flow.csv
# 12 network-wide-pcap-capture/network-wide/output/network-wide-normal-20_fix_ord.pcap_Flow.csv
# 13 network-wide-pcap-capture/network-wide/output/network-wide-normal-21_fix_ord.pcap_Flow.csv
# 14 network-wide-pcap-capture/network-wide/output/network-wide-normal-17_fix_ord.pcap_Flow.csv
# 15 network-wide-pcap-capture/network-wide/output/network-wide-normal-16_fix_ord.pcap_Flow.csv
# 16 network-wide-pcap-capture/network-wide/output/network-wide-normal-26_fix_ord.pcap_Flow.csv
# 17 network-wide-pcap-capture/network-wide/output/network-wide-normal-28_fix_ord.pcap_Flow.csv
# 18 network-wide-pcap-capture/network-wide/output/network-wide-normal-27_fix_ord.pcap_Flow.csv
# 19 network-wide-pcap-capture/network-wide/output/network-wide-normal-29_fix_ord.pcap_Flow.csv
# 20 ied4c/ied4c-network-capture/output/veth8bc3408-normal-10_fix_ord.pcap_Flow.csv
# 21 ied4c/ied4c-network-capture/output/veth8bc3408-normal-5_fix_ord.pcap_Flow.csv
# 22 ied4c/ied4c-network-capture/output/veth8bc3408-normal-6_fix_ord.pcap_Flow.csv
# 23 ied4c/ied4c-network-capture/output/veth8bc3408-normal-8_fix_ord.pcap_Flow.csv
# 24 ied4c/ied4c-network-capture/output/veth8bc3408-normal-11_fix_ord.pcap_Flow.csv
# 25 ied4c/ied4c-network-capture/output/veth8bc3408-normal-4_fix_ord.pcap_Flow.csv
# 26 ied4c/ied4c-network-capture/output/veth8bc3408-normal-7_fix_ord.pcap_Flow.csv
# 27 ied4c/ied4c-network-capture/output/veth8bc3408-normal-9_fix_ord.pcap_Flow.csv
# 28 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-4_fix_ord.pcap_Flow.csv
# 29 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-9_fix_ord.pcap_Flow.csv
# 30 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-5_fix_ord.pcap_Flow.csv
# 31 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-10_fix_ord.pcap_Flow.csv
# 32 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-7_fix_ord.pcap_Flow.csv
# 33 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-6_fix_ord.pcap_Flow.csv
# 34 ied1b/ied1b-network-capture/output/vethd9e14c0-normal-8_fix_ord.pcap_Flow.csv
# 35 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-27_fix_ord.pcap_Flow.csv
# 36 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-23_fix_ord.pcap_Flow.csv
# 37 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-14_fix_ord.pcap_Flow.csv
# 38 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-16_fix_ord.pcap_Flow.csv
# 39 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-18_fix_ord.pcap_Flow.csv
# 40 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-15_fix_ord.pcap_Flow.csv
# 41 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-25_fix_ord.pcap_Flow.csv
# 42 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-28_fix_ord.pcap_Flow.csv
# 43 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-29_fix_ord.pcap_Flow.csv
# 44 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-22_fix_ord.pcap_Flow.csv
# 45 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-17_fix_ord.pcap_Flow.csv
# 46 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-19_fix_ord.pcap_Flow.csv
# 47 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-13_fix_ord.pcap_Flow.csv
# 48 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-21_fix_ord.pcap_Flow.csv
# 49 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-26_fix_ord.pcap_Flow.csv
# 50 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-30_fix_ord.pcap_Flow.csv
# 51 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-20_fix_ord.pcap_Flow.csv
# 52 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-24_fix_ord.pcap_Flow.csv
# 53 scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-normal-31_fix_ord.pcap_Flow.csv
# 54 central-agent/central-agent-network-capture/output/veth460b141-normal_fix_ord.pcap_Flow.csv
# 55 ied1a/ied1a-network-capture/output/veth4edc015-normal-9_fix_ord.pcap_Flow.csv
# 56 ied1a/ied1a-network-capture/output/veth4edc015-normal-6_fix_ord.pcap_Flow.csv
# 57 ied1a/ied1a-network-capture/output/veth4edc015-normal-7_fix_ord.pcap_Flow.csv
# 58 ied1a/ied1a-network-capture/output/veth4edc015-normal-5_fix_ord.pcap_Flow.csv
# 59 ied1a/ied1a-network-capture/output/veth4edc015-normal-11_fix_ord.pcap_Flow.csv
# 60 ied1a/ied1a-network-capture/output/veth4edc015-normal-10_fix_ord.pcap_Flow.csv
# 61 ied1a/ied1a-network-capture/output/veth4edc015-normal-4_fix_ord.pcap_Flow.csv
# 62 ied1a/ied1a-network-capture/output/veth4edc015-normal-8_fix_ord.pcap_Flow.csv
# list of attack csv dataset directories under ./ModbusDataset/attack/*
# 1 external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv
# 2 external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv
# 3 external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv
# 4 external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv
# 5 external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv
# 6 external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv
# 7 external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv
# 8 external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv
# 9 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# 10 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# 11 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# 12 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# 13 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# 14 compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# 15 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv
# 16 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# 17 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# 18 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv
# 19 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# 20 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# 21 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# 22 compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# 23 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv
# 24 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv
# 25 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv
# 26 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv
# 27 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv
# 28 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv
# 29 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv
# 30 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv
# 31 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv
# 32 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-0_fix_ord.pcap_Flow.csv
# 33 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-8_fix_ord.pcap_Flow.csv
# 34 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-11_fix_ord.pcap_Flow.csv
# 35 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-2_fix_ord.pcap_Flow.csv
# 36 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-15_fix_ord.pcap_Flow.csv
# 37 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-7_fix_ord.pcap_Flow.csv
# 38 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-13_fix_ord.pcap_Flow.csv
# 39 compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-9_fix_ord.pcap_Flow.csv
# 40 compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# 41 compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# 42 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# 43 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# 44 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# 45 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# 46 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# 47 compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv
# 48 compromised-scada/substation-wide-capture/output/substation-15_fix_ord.pcap_Flow.csv
# 49 compromised-scada/substation-wide-capture/output/substation-16_fix_ord.pcap_Flow.csv
# 50 compromised-scada/substation-wide-capture/output/substation-9_fix_ord.pcap_Flow.csv
# 51 compromised-scada/substation-wide-capture/output/substation-10_fix_ord.pcap_Flow.csv
# 52 compromised-scada/substation-wide-capture/output/substation-6_fix_ord.pcap_Flow.csv
# 53 compromised-scada/substation-wide-capture/output/substation-14_fix_ord.pcap_Flow.csv
# 54 compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv
# 55 compromised-scada/substation-wide-capture/output/substation-8_fix_ord.pcap_Flow.csv
# 56 compromised-scada/substation-wide-capture/output/substation-13_fix_ord.pcap_Flow.csv
# 57 compromised-scada/substation-wide-capture/output/substation-12_fix_ord.pcap_Flow.csv
# 58 compromised-scada/substation-wide-capture/output/substation-0_fix_ord.pcap_Flow.csv
# 59 compromised-scada/substation-wide-capture/output/substation-3_fix_ord.pcap_Flow.csv
# 60 compromised-scada/substation-wide-capture/output/substation-7_fix_ord.pcap_Flow.csv
# 61 compromised-scada/substation-wide-capture/output/substation-4_fix_ord.pcap_Flow.csv
# 62 compromised-scada/substation-wide-capture/output/substation-5_fix_ord.pcap_Flow.csv
# 63 compromised-scada/substation-wide-capture/output/substation-17_fix_ord.pcap_Flow.csv
# 64 compromised-scada/substation-wide-capture/output/substation-11_fix_ord.pcap_Flow.csv
# 65 compromised-scada/substation-wide-capture/output/substation-2_fix_ord.pcap_Flow.csv
# 66 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# 67 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# 68 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# 69 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# 70 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# 71 compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# 72 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# 73 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# 74 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# 75 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# 76 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# 77 compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# 78 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-19_fix_ord.pcap_Flow.csv
# 79 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-12_fix_ord.pcap_Flow.csv
# 80 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-9_fix_ord.pcap_Flow.csv
# 81 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-18_fix_ord.pcap_Flow.csv
# 82 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-13_fix_ord.pcap_Flow.csv
# 83 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-7_fix_ord.pcap_Flow.csv
# 84 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-4_fix_ord.pcap_Flow.csv
# 85 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-14_fix_ord.pcap_Flow.csv
# 86 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-17_fix_ord.pcap_Flow.csv
# 87 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-6_fix_ord.pcap_Flow.csv
# 88 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-11_fix_ord.pcap_Flow.csv
# 89 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-16_fix_ord.pcap_Flow.csv
# 90 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-8_fix_ord.pcap_Flow.csv
# 91 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-3_fix_ord.pcap_Flow.csv
# 92 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv
# 93 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-5_fix_ord.pcap_Flow.csv
# 94 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-2_fix_ord.pcap_Flow.csv
# 95 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-1_fix_ord.pcap_Flow.csv
# 96 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-0_fix_ord.pcap_Flow.csv
# 97 compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-10_fix_ord.pcap_Flow.csv
# 98 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# 99 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-4_fix_ord.pcap_Flow.csv
# 100 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# 101 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-3_fix_ord.pcap_Flow.csv
# 102 compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-2_fix_ord.pcap_Flow.csv
# 103 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# 104 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# 105 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# 106 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# 107 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# 108 compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv

# %% [markdown]
# #### Labeling functions

# %%
from utils import format_csv_for_labeling,merge_datasets


def read_csvs_from_path_and_reformat(path):
    df = pd.read_csv(path, encoding='cp1252')

    df = format_csv_for_labeling(df)
    print("labels after pre-processing:\n", df["Label"].value_counts())

    int32_columns = ["Src Port", "Dst Port", "Flow Duration", "Total Fwd Packet", "Total Bwd packets", "Total Length of Fwd Packet", "Total Length of Bwd Packet", "Fwd Packet Length Max",
        "Fwd Packet Length Min", "Bwd Packet Length Max", "Bwd Packet Length Min", "Flow IAT Max", "Flow IAT Min", "Fwd IAT Total", "Fwd IAT Max", "Fwd IAT Min", "Bwd IAT Total",
        "Bwd IAT Max", "Bwd IAT Min", "Fwd PSH Flags", "Bwd PSH Flags", "Fwd URG Flags", "Bwd URG Flags", "Packet Length Min", "Packet Length Max", "FIN Flag Count", "SYN Flag Count", "RST Flag Count", "PSH Flag Count",
        "ACK Flag Count", "URG Flag Count", "CWR Flag Count", "ECE Flag Count", "Subflow Fwd Packets", "Subflow Fwd Bytes",
        "Subflow Bwd Packets", "Subflow Bwd Bytes", "FWD Init Win Bytes", "Bwd Init Win Bytes", "Fwd Act Data Pkts", "Fwd Seg Size Min", "Active Max",
        "Active Min", "Idle Max", "Idle Min"]

    int16_columns = ["Fwd Header Length", "Bwd Header Length", "ICMP Code", "ICMP Type"]

    for column in int32_columns:
        df[column] = df[column].astype('int32')

    for column in int16_columns:
        df[column] = df[column].astype('int16')

    return df


def label_rest_as_benign_and_write_csv(df, input_path,print_index=False):
    """
    This function is called when all labelling of malicious flows is completed. Anything that has not yet received a label
    so far is labelled as Benign.
    write dataframe to csv file in ready directory (create if not exist )
    """
    df["Label"]=df["Label"].mask(df["Label"] == "NeedManualLabel", "BENIGN")
    print("label count after labelling:\r\n", df["Label"].value_counts())
    # Construct the ready directory path alongside output
    ready_dir = os.path.join(os.path.dirname(os.path.dirname(input_path)), 'ready')
    os.makedirs(ready_dir, exist_ok=True)
    filename = os.path.basename(input_path)
    name, ext = os.path.splitext(filename)  # Split the extension (name, ".csv")
    cleaned_name = name.replace("_fix_ord.pcap_Flow", "-labeled")
    # Construct full output path
    output_path = os.path.join(ready_dir, f"{cleaned_name}{ext}")  # Append extension
    # Adds line numbers in the first column if print_index is set to true
    if print_index:
        df.reset_index(inplace=True, drop=True)
        df.index += 1
        df.index.name = 'id'
        df.to_csv(output_path)
    else:
        df.to_csv(output_path, index=False)

def sort_df(_df):
    """    
    return sorted dataframe vertically with respect to TimeStamps
    """    
    new_df_sorted = _df.sort_values(by='Timestamp', ascending=True)
    new_df_sorted = new_df_sorted.reset_index(drop=True)
    return new_df_sorted

# %% [markdown]
# #### Label All csv files in benign folder as "BENIGN"
#
# Uncomment next lines of code if the labeling of the benign dataset not occured yet !

# %%
# for _dir in modbus.dataset["benign_dataset_dir"]:
#     label_rest_as_benign_and_write_csv(read_csvs_from_path_and_reformat(_dir) ,_dir)
# Out:
# labels after pre-processing:
#  Label
# NeedManualLabel    153041
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153041
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153868
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153868
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    152394
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    152394
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153812
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153812
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    71348
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    71348
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153378
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153378
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153357
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153357
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    152144
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    152144
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153155
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153155
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    145758
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    145758
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153495
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153495
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153965
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153965
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153696
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153696
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153183
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153183
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    154269
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    154269
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153063
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153063
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    152816
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    152816
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    153331
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    153331
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    152371
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    152371
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    167481
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    167481
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    166975
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    166975
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169492
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169492
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169872
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169872
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    36343
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    36343
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    165962
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    165962
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    170813
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    170813
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169829
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169829
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116562
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116562
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116551
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116551
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116552
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116552
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    3454
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    3454
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116552
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116552
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116550
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116550
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    116550
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    116550
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157181
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157181
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    158196
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    158196
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    150252
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    150252
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157615
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157615
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    156148
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    156148
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157794
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157794
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157414
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157414
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    156226
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    156226
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157384
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157384
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    158211
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    158211
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157030
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157030
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157109
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157109
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    154597
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    154597
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157719
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157719
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157377
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157377
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    158617
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    158617
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157872
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157872
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    157458
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    157458
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    93910
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    93910
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    17807
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    17807
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169101
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169101
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169660
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169660
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    170566
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    170566
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    170002
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    170002
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    42147
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    42147
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    167997
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    167997
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    167254
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    167254
# Name: count, dtype: int64
# labels after pre-processing:
#  Label
# NeedManualLabel    169112
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    169112
# Name: count, dtype: int64

# %% [markdown]
# #### Attack Labeling depends on the log Attack , Timestamp columns

# %% [markdown]
# In the log only the completed attacks are reliable. for example
# ```md
# 2023-02-01 13:06:29.2, Brute force or specific coil. Address: 0
# 2023-02-01 13:06:29.201, Brute force or specific - Complete
# ```
# 🟢 It's okay but
# ```md
# 2023-02-01 13:06:29.2, Brute force or specific coil. Address: 0
# ```
# 🔴 It may not be implemented literally at all! !
#
# ❗Unfortunately no exact logging happend in attack/attacker logs
# Complete Timestamp of an attack might be before ending the flow/connection or after that about 2 minutes !!!
# Or the timestamp in the log may be earlier than the timestamp of the .pcap files (SYN).
# Received timestamps of a flow might be different in different nodes make it hard to label automatically.

# %%
def clean_label(label_str):
    """Clean label by removing multiple unwanted substrings/characters and applying specific conversions"""
    conversions = {
        'REPLAY': 'BASELINE REPLAY',
        'STACKED MODBUS FRAMES': 'FRAME STACKING',
        'FALSE DATA INJECTION': 'PAYLOAD INJECTION'
    }
    
    label_str = re.sub(r'BASELINE|STARTING|ATTACK|ADDRESS|Complete|or specific|coil|RANGE|range|,|-|\.|:[^:]*$', '', label_str, flags=re.IGNORECASE)
    label_str = re.sub(r'\s+', ' ', label_str).strip()
    label_str = re.sub(r'\s-\s*$', '', label_str)
    label_str = label_str.upper()
    
    for old, new in conversions.items():
        label_str = label_str.replace(old, new)
    
    return label_str

def log_pairs_from_dir(_attack_log_dirs):
    """
    extract target ip, start , end and  attack label pairs from logs (csv)
    make it ready to be used in label_flows second argument
    """
    # sort attak_df beacuse of overlapped flow durations results in multiple labels 
    # Priority: Earlier flows in attack_df take precedence for labeling when multiple flows contain attack interval
    attack_log_df = sort_df(merge_datasets(_attack_log_dirs))
    #  Find rows in attack_log_df where 'Attack' contains 'Complete'
    # Create a mask for rows where 'Attack' contains 'Complete'
    complete_mask = attack_log_df['Attack'].str.contains('Complete', na=False)
    
    ## sending response to the server (compromised-ied logs)
    complete_mask |= attack_log_df['Attack'].str.contains('Sending', na=False)

    # Find valid attack pairs and convert to numpy datetime64 upfront
    pairs = []
    for i in attack_log_df.index[complete_mask]:
        if i > 0:
            start = np.datetime64(attack_log_df.at[i-1, 'Timestamp'],'us')
            end = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            if 'TargetIP' in attack_log_df.columns:
                ip = attack_log_df.at[i,'TargetIP']
            else:
                ip=None
            label = clean_label(attack_log_df.at[i, 'Attack'])
            pairs.append((start, end,ip, label))

    no_complete_mask = ~(complete_mask | complete_mask.shift(-1, fill_value=False))

    for i in attack_log_df.index[no_complete_mask]:
        if i > 0:
            start = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            end = np.datetime64(attack_log_df.at[i, 'Timestamp'],'us')
            label = clean_label(attack_log_df.at[i, 'Attack'])
            if 'TargetIP' in attack_log_df.columns:
                ip = attack_log_df.at[i,'TargetIP']
            else:
                ip=None
            pairs.append((start, end,ip, label))
    return pairs 

def label_flows(_attack_dir,_attack_pairs,src_ip_list=None ,dst_ip_list=None,
                max_start_timestamp_tolerate= np.timedelta64(100_000, 'us'),
                max_end_timestamp_tolarate=np.timedelta64(1_000_000, 'us'),
                reverse_target=False):
    """
    label flows of the dataset csv file with respect to the logs overlaping timestamp 
    then change the _attack_dir "Label" Column.
    Timestamps are in MICROSECONDS (!) Unix time. Note that the CSV files are in the UTC timezone.
    """

    print("Attack directory ------------------------------",_attack_dir)
        
    attack_df= read_csvs_from_path_and_reformat(_attack_dir)
    attack_df['end_time'] = attack_df['Timestamp'] + pd.to_timedelta(attack_df['Flow Duration'], unit='us')
    attack_df=sort_df(attack_df)

    # Convert to numpy arrays for vectorized operations
    starts = attack_df['Timestamp'].values.astype('datetime64[us]')
    ends = attack_df['end_time'].values.astype('datetime64[us]')
    if not reverse_target:
        dst_ips = attack_df['Dst IP'].values
    else:
        dst_ips = attack_df['Src IP'].values
    labels = attack_df['Label'].values
    orig_indices = attack_df.index.values
    custom_mask = (attack_df['Label'] == "NeedManualLabel").values

    # Precompute mask for unlabeled flows
    custom_mask &= (labels == "NeedManualLabel")
    if src_ip_list is not None:
        custom_mask &= attack_df["Src IP"].isin(src_ip_list).values
    if dst_ip_list is not None:
        custom_mask &= attack_df["Dst IP"].isin(dst_ip_list).values

   # Collect updates to minimize DataFrame operations
    updates = []

    # Process each attack pair
    for start_p, end_p,ip, new_label in _attack_pairs:

        # Find flows that:
        # 1. logging attack Complete within 1 seconds of the flow end_time
        # 2. logging attack start within 0.01 seconds after the flow start
        # Find candidate flows using binary search ( sorted attack_df by start timestamp)

        start_left_interval = bisect_left(starts, start_p - max_start_timestamp_tolerate)
        end_right_interval = bisect_right(starts, start_p + max_start_timestamp_tolerate)

        for idx in range(start_left_interval,end_right_interval):
            if custom_mask[idx] and (np.abs(ends[idx] - end_p)<=max_end_timestamp_tolarate ):
                if ip is not None:
                    if ip!=dst_ips[idx]:
                        continue
                orig_idx = orig_indices[idx]
                updates.append((orig_idx, new_label))
                custom_mask[idx] = False
                break  # Only label the first matching flow

    # Apply all updates at once
    if updates:
        update_indices, update_labels = zip(*updates)
        attack_df.loc[list(update_indices), 'Label'] = list(update_labels)

    # Finalize by labeling remaining flows as benign and writing to CSV
    label_rest_as_benign_and_write_csv(attack_df, _attack_dir)

# %% [markdown]
# ##### Read no labeled CSVs from output directory, save labeled CSVs in ready directory, So you are able to run below scripts multiple time with different hyper-parameters and check if it is labeling in a correct way

# %% [markdown]
# ##### External Attacks
# 🟢 Attacks from an unknown IP address (185.175.0.7) targeting 185.175.0.4.
#
# ❗Attacks occured in separable detectable interval and recognizable by the attacker ip

# %%
attack_pairs = log_pairs_from_dir(modbus.dataset["attack_log_dir"]["external"])
for att_dir in modbus.dataset["attack_dataset_dir"]["external"] :
    label_flows(att_dir,attack_pairs,src_ip_list=["185.175.0.7"],dst_ip_list=["185.175.0.4"],
                         max_start_timestamp_tolerate=np.timedelta64(10_000_000, 'us'),
                         max_end_timestamp_tolarate=np.timedelta64(100_000_000, 'us'))
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/external/network-wide/output/network-wide-normal-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    68931
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BRUTE FORCE    54206
# BENIGN         14725
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/network-wide/output/network-wide-normal-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    152398
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 141333
# BRUTE FORCE             11027
# RECON                      32
# QUERY FLOODING              2
# LENGTH MANIPULATION         1
# BASELINE REPLAY             1
# PAYLOAD INJECTION           1
# FRAME STACKING              1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied4c/ied4c-network-capture/output/veth8bc3408-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    59666
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    59666
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/external-attacker/external-attacker-network-capture/output/veth665f3cf-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    65626
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BRUTE FORCE            65556
# BENIGN                    32
# RECON                     32
# QUERY FLOODING             2
# LENGTH MANIPULATION        1
# BASELINE REPLAY            1
# PAYLOAD INJECTION          1
# FRAME STACKING             1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied1b/ied1b-network-capture/output/vethd9e14c0-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    36318
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    36318
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/scada-hmi/scada-hmi-network-capture/output/veth5bbeaa2-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    155217
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    155217
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/central-agent/central-agent-network-capture/output/veth460b141-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    548
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    548
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/external/ied1a/ied1a-network-capture/output/veth4edc015-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    125432
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BRUTE FORCE            65556
# BENIGN                 59838
# RECON                     32
# QUERY FLOODING             2
# LENGTH MANIPULATION        1
# BASELINE REPLAY            1
# PAYLOAD INJECTION          1
# FRAME STACKING             1
# Name: count, dtype: int64

# %%
string_types = [item[3] for item in attack_pairs]
# Use Counter to get the frequency of each string
type_counts = Counter(string_types)

print(type_counts)
# Output: Counter({'BRUTE FORCE': 2, 'OPTIMIZED': 1})

# You can then access the count for a specific key
print(f"Count for 'BRUTE FORCE': {type_counts['BRUTE FORCE']}")
# Out:
# Counter({'BRUTE FORCE': 75982, 'RECON': 44, 'QUERY FLOODING': 8, 'LENGTH MANIPULATION': 1, 'BASELINE REPLAY': 1, 'PAYLOAD INJECTION': 1, 'FRAME STACKING': 1})
# Count for 'BRUTE FORCE': 75982

# %% [markdown]
# ##### Compromised SCADA Attacks
# 🟢 Attacks from 185.175.0.3 targeting 185.175.0.4 ,185.175.0.5 and 185.175.0.8.Days 12 to 14 in attack logs are missed in pcaps.
#
# ❗Attacks occured  separable detectable interval (no need for manual check)

# %%
# uncomment next lines of code if the labeling of the external attack dataset does not occured yet  !

dates = ["03-12-2023", "03-13-2023"]
## exclude dates 12,13,14 from attack log dirs (relative packets not present!)
filtered_list = list(filter(lambda x: all(date not in x for date in dates), modbus.dataset["attack_log_dir"]["compromised-scada"]))
attack_pairs = log_pairs_from_dir(filtered_list)

for att_dir in modbus.dataset["attack_dataset_dir"]["compromised-scada"]  :
    label_flows(att_dir,attack_pairs,src_ip_list=["185.175.0.3"],
                dst_ip_list=["185.175.0.4","185.175.0.5","185.175.0.8"],
             max_start_timestamp_tolerate=np.timedelta64(5_000, 'us'),
                         max_end_timestamp_tolarate=np.timedelta64(100_000_000, 'us'))
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    160689
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN               160253
# BRUTE FORCE             428
# FRAME STACKING            4
# PAYLOAD INJECTION         3
# BASELINE REPLAY           1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158034
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 130473
# BRUTE FORCE             27398
# RECON                      48
# PAYLOAD INJECTION          36
# QUERY FLOODING             28
# FRAME STACKING             23
# BASELINE REPLAY            20
# LENGTH MANIPULATION         8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    146703
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127693
# BRUTE FORCE             18882
# BASELINE REPLAY            36
# FRAME STACKING             24
# LENGTH MANIPULATION        20
# QUERY FLOODING             20
# RECON                      16
# PAYLOAD INJECTION          12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150558
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 121087
# BRUTE FORCE             29231
# FRAME STACKING             48
# BASELINE REPLAY            48
# RECON                      44
# PAYLOAD INJECTION          40
# LENGTH MANIPULATION        36
# QUERY FLOODING             24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    169162
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN             169138
# QUERY FLOODING          8
# BASELINE REPLAY         5
# RECON                   4
# FRAME STACKING          4
# BRUTE FORCE             3
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    54280
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    54280
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-7_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    16102
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 11933
# BRUTE FORCE             4135
# BASELINE REPLAY           10
# PAYLOAD INJECTION          8
# RECON                      8
# FRAME STACKING             4
# LENGTH MANIPULATION        4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123170
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 77549
# BRUTE FORCE            45413
# BASELINE REPLAY           52
# PAYLOAD INJECTION         48
# QUERY FLOODING            40
# FRAME STACKING            32
# LENGTH MANIPULATION       24
# RECON                     12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    121545
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 87865
# BRUTE FORCE            33419
# BASELINE REPLAY           84
# FRAME STACKING            52
# QUERY FLOODING            36
# LENGTH MANIPULATION       33
# PAYLOAD INJECTION         32
# RECON                     24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123174
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    123170
# RECON          4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    120307
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 87037
# BRUTE FORCE            33027
# RECON                     48
# QUERY FLOODING            48
# BASELINE REPLAY           47
# PAYLOAD INJECTION         40
# FRAME STACKING            36
# LENGTH MANIPULATION       24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123210
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 94428
# BRUTE FORCE            28556
# LENGTH MANIPULATION       68
# FRAME STACKING            44
# PAYLOAD INJECTION         36
# QUERY FLOODING            32
# BASELINE REPLAY           30
# RECON                     16
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    122948
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 85553
# BRUTE FORCE            37171
# FRAME STACKING            51
# BASELINE REPLAY           49
# QUERY FLOODING            40
# PAYLOAD INJECTION         32
# RECON                     28
# LENGTH MANIPULATION       24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    122497
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 85092
# BRUTE FORCE            37163
# LENGTH MANIPULATION       55
# BASELINE REPLAY           45
# QUERY FLOODING            44
# PAYLOAD INJECTION         40
# RECON                     34
# FRAME STACKING            24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150177
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 113625
# BRUTE FORCE             36256
# BASELINE REPLAY            69
# LENGTH MANIPULATION        59
# PAYLOAD INJECTION          48
# QUERY FLOODING             48
# RECON                      48
# FRAME STACKING             24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-16_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    104203
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 100030
# BRUTE FORCE              4135
# RECON                      12
# BASELINE REPLAY            10
# PAYLOAD INJECTION           8
# FRAME STACKING              4
# LENGTH MANIPULATION         4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    155022
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 136782
# BRUTE FORCE             17994
# QUERY FLOODING             68
# BASELINE REPLAY            51
# PAYLOAD INJECTION          40
# RECON                      36
# LENGTH MANIPULATION        31
# FRAME STACKING             20
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150390
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 108932
# BRUTE FORCE             41231
# FRAME STACKING             63
# BASELINE REPLAY            45
# PAYLOAD INJECTION          40
# LENGTH MANIPULATION        28
# QUERY FLOODING             28
# RECON                      23
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-12_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    157042
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 144317
# BRUTE FORCE             12639
# LENGTH MANIPULATION        32
# FRAME STACKING             16
# PAYLOAD INJECTION          12
# BASELINE REPLAY            10
# QUERY FLOODING              8
# RECON                       8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    148852
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 110842
# BRUTE FORCE             37708
# QUERY FLOODING             72
# BASELINE REPLAY            65
# FRAME STACKING             44
# PAYLOAD INJECTION          41
# RECON                      40
# LENGTH MANIPULATION        40
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-10_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    146990
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 106999
# BRUTE FORCE             39699
# BASELINE REPLAY            79
# RECON                      52
# QUERY FLOODING             51
# FRAME STACKING             43
# LENGTH MANIPULATION        39
# PAYLOAD INJECTION          28
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-14_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158355
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN               157921
# BRUTE FORCE             426
# FRAME STACKING            4
# PAYLOAD INJECTION         3
# BASELINE REPLAY           1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    153491
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 128210
# BRUTE FORCE             25113
# PAYLOAD INJECTION          40
# FRAME STACKING             39
# BASELINE REPLAY            29
# RECON                      28
# LENGTH MANIPULATION        16
# QUERY FLOODING             16
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    143810
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 81937
# BRUTE FORCE            61691
# QUERY FLOODING            40
# BASELINE REPLAY           37
# LENGTH MANIPULATION       36
# FRAME STACKING            29
# PAYLOAD INJECTION         28
# RECON                     12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-8_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158898
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 138176
# BRUTE FORCE             20650
# BASELINE REPLAY            24
# QUERY FLOODING             16
# LENGTH MANIPULATION        12
# FRAME STACKING             12
# RECON                       8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-11_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    152946
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 132694
# BRUTE FORCE             20097
# PAYLOAD INJECTION          43
# FRAME STACKING             31
# LENGTH MANIPULATION        28
# QUERY FLOODING             28
# RECON                      15
# BASELINE REPLAY            10
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    149499
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 119903
# BRUTE FORCE             29276
# LENGTH MANIPULATION        68
# FRAME STACKING             60
# BASELINE REPLAY            58
# RECON                      54
# PAYLOAD INJECTION          48
# QUERY FLOODING             32
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-15_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    158788
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    158788
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-7_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    160686
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 152326
# BRUTE FORCE              8258
# FRAME STACKING             24
# QUERY FLOODING             20
# RECON                      20
# PAYLOAD INJECTION          20
# BASELINE REPLAY            10
# LENGTH MANIPULATION         8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-13_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    155721
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 147408
# BRUTE FORCE              8259
# LENGTH MANIPULATION        16
# BASELINE REPLAY            10
# FRAME STACKING              8
# QUERY FLOODING              8
# RECON                       8
# PAYLOAD INJECTION           4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/scada-hmi/scada-hmi-network-capture/output/veth291ab9a-9_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    152904
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127829
# BRUTE FORCE             24799
# BASELINE REPLAY            75
# FRAME STACKING             61
# PAYLOAD INJECTION          48
# RECON                      40
# QUERY FLOODING             36
# LENGTH MANIPULATION        16
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    1839
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    1839
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    5943
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    5943
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150281
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 128425
# BRUTE FORCE             21507
# QUERY FLOODING             80
# BASELINE REPLAY            71
# PAYLOAD INJECTION          66
# LENGTH MANIPULATION        60
# RECON                      40
# FRAME STACKING             32
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    167779
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    167779
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    71401
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    71401
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    139920
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 95450
# BRUTE FORCE            44239
# FRAME STACKING            61
# LENGTH MANIPULATION       52
# RECON                     36
# QUERY FLOODING            32
# BASELINE REPLAY           30
# PAYLOAD INJECTION         20
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    157454
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 140850
# BRUTE FORCE             16419
# BASELINE REPLAY            40
# FRAME STACKING             32
# PAYLOAD INJECTION          32
# RECON                      32
# QUERY FLOODING             27
# LENGTH MANIPULATION        22
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    166092
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 153304
# BRUTE FORCE             12725
# BASELINE REPLAY            15
# RECON                      12
# QUERY FLOODING             12
# FRAME STACKING             12
# PAYLOAD INJECTION           8
# LENGTH MANIPULATION         4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-15_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    149324
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN               148888
# BRUTE FORCE             428
# FRAME STACKING            4
# PAYLOAD INJECTION         3
# BASELINE REPLAY           1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-16_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    142746
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    142746
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-9_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    154055
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 137439
# BRUTE FORCE             16534
# BASELINE REPLAY            34
# FRAME STACKING             24
# QUERY FLOODING             16
# LENGTH MANIPULATION         8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-10_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    142526
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 121532
# BRUTE FORCE             20680
# BASELINE REPLAY            80
# FRAME STACKING             60
# PAYLOAD INJECTION          48
# RECON                      48
# QUERY FLOODING             43
# LENGTH MANIPULATION        35
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    134832
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 118140
# BRUTE FORCE             16520
# RECON                      40
# FRAME STACKING             28
# QUERY FLOODING             28
# PAYLOAD INJECTION          28
# BASELINE REPLAY            25
# LENGTH MANIPULATION        23
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-14_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    151744
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 143431
# BRUTE FORCE              8259
# LENGTH MANIPULATION        16
# BASELINE REPLAY            10
# FRAME STACKING              8
# QUERY FLOODING              8
# RECON                       8
# PAYLOAD INJECTION           4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    137416
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 101209
# BRUTE FORCE             35983
# FRAME STACKING             56
# QUERY FLOODING             44
# PAYLOAD INJECTION          40
# BASELINE REPLAY            40
# LENGTH MANIPULATION        28
# RECON                      16
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-8_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    153977
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 137386
# BRUTE FORCE             16509
# RECON                      24
# PAYLOAD INJECTION          16
# LENGTH MANIPULATION        12
# QUERY FLOODING             12
# BASELINE REPLAY            10
# FRAME STACKING              8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-13_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    152105
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 139633
# BRUTE FORCE             12386
# LENGTH MANIPULATION        32
# FRAME STACKING             16
# PAYLOAD INJECTION          12
# BASELINE REPLAY            10
# QUERY FLOODING              8
# RECON                       8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-12_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    150793
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 134433
# BRUTE FORCE             16213
# PAYLOAD INJECTION          39
# FRAME STACKING             31
# QUERY FLOODING             28
# LENGTH MANIPULATION        24
# RECON                      15
# BASELINE REPLAY            10
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    21
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    21
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    140103
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 102988
# BRUTE FORCE             36861
# LENGTH MANIPULATION        56
# RECON                      52
# QUERY FLOODING             40
# PAYLOAD INJECTION          40
# BASELINE REPLAY            35
# FRAME STACKING             31
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-7_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    146062
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 129074
# BRUTE FORCE             16852
# FRAME STACKING             39
# PAYLOAD INJECTION          28
# BASELINE REPLAY            25
# QUERY FLOODING             24
# RECON                      12
# LENGTH MANIPULATION         8
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    138231
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 102695
# BRUTE FORCE             35255
# BASELINE REPLAY            71
# QUERY FLOODING             68
# PAYLOAD INJECTION          42
# LENGTH MANIPULATION        40
# FRAME STACKING             36
# RECON                      24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    136012
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 108646
# BRUTE FORCE             27120
# QUERY FLOODING             60
# BASELINE REPLAY            58
# PAYLOAD INJECTION          40
# RECON                      36
# LENGTH MANIPULATION        32
# FRAME STACKING             20
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-17_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    134635
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 130462
# BRUTE FORCE              4135
# RECON                      12
# BASELINE REPLAY            10
# PAYLOAD INJECTION           8
# FRAME STACKING              4
# LENGTH MANIPULATION         4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-11_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    132577
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 88521
# BRUTE FORCE            43816
# BASELINE REPLAY           64
# QUERY FLOODING            44
# RECON                     44
# FRAME STACKING            32
# PAYLOAD INJECTION         32
# LENGTH MANIPULATION       24
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-scada/substation-wide-capture/output/substation-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    136485
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 115502
# BRUTE FORCE             20670
# LENGTH MANIPULATION        68
# BASELINE REPLAY            63
# FRAME STACKING             56
# RECON                      54
# PAYLOAD INJECTION          48
# QUERY FLOODING             24
# Name: count, dtype: int64

# %% [markdown]
# ##### Compromised IED Attacks
# 🔴 Scada will initiate the connections Attacks from 185.175.0.5 targeting 185.175.0.2 ( reverse direction of the flow).
# ❗not separable detectable interval (need high manual checking)

# %%
attack_pairs = log_pairs_from_dir(modbus.dataset["attack_log_dir"]["compromised-ied"])

for att_dir in modbus.dataset["attack_dataset_dir"]["compromised-ied"]  :
    label_flows(att_dir,attack_pairs,src_ip_list=["185.175.0.2"],
                dst_ip_list=["185.175.0.5"],
             max_start_timestamp_tolerate=np.timedelta64(15_000, 'us'),
                         max_end_timestamp_tolarate=np.timedelta64(100_000_000, 'us'),reverse_target=True)
# Out:
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    176157
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    176157
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    173315
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    173315
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    176179
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    176179
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    174112
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    174112
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    173980
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    173980
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied4c/ied4c-network-captures/output/vethe685ac9-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    75894
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    75894
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    126147
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126086
# BASELINE REPLAY            26
# PAYLOAD INJECTION          10
# QUERY FLOODING              8
# LENGTH MANIPULATION         7
# FRAME STACKING              6
# DELAY RESPONSE              4
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127019
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126946
# PAYLOAD INJECTION          19
# DELAY RESPONSE             13
# LENGTH MANIPULATION        12
# QUERY FLOODING             11
# BASELINE REPLAY             9
# FRAME STACKING              9
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    126800
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126729
# PAYLOAD INJECTION          15
# LENGTH MANIPULATION        14
# BASELINE REPLAY            12
# QUERY FLOODING             11
# DELAY RESPONSE             10
# FRAME STACKING              9
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    25393
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 25381
# QUERY FLOODING             3
# LENGTH MANIPULATION        3
# BASELINE REPLAY            3
# FRAME STACKING             2
# PAYLOAD INJECTION          1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127116
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127052
# PAYLOAD INJECTION          18
# LENGTH MANIPULATION        13
# FRAME STACKING             12
# QUERY FLOODING              9
# DELAY RESPONSE              6
# BASELINE REPLAY             6
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1b/ied1b-network-captures/output/vethc76bd3f-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    126629
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126553
# QUERY FLOODING             19
# PAYLOAD INJECTION          15
# FRAME STACKING             13
# DELAY RESPONSE             10
# LENGTH MANIPULATION        10
# BASELINE REPLAY             9
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-19_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    123142
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 123128
# LENGTH MANIPULATION         4
# QUERY FLOODING              3
# BASELINE REPLAY             3
# FRAME STACKING              2
# DELAY RESPONSE              1
# PAYLOAD INJECTION           1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-12_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    129313
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 129296
# LENGTH MANIPULATION         6
# FRAME STACKING              5
# PAYLOAD INJECTION           3
# DELAY RESPONSE              2
# QUERY FLOODING              1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-9_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    124394
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 124377
# DELAY RESPONSE              5
# LENGTH MANIPULATION         4
# QUERY FLOODING              3
# PAYLOAD INJECTION           2
# FRAME STACKING              2
# BASELINE REPLAY             1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-18_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    133424
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 133404
# PAYLOAD INJECTION           5
# LENGTH MANIPULATION         4
# DELAY RESPONSE              4
# QUERY FLOODING              3
# FRAME STACKING              2
# BASELINE REPLAY             2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-13_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    129610
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 129590
# PAYLOAD INJECTION           8
# FRAME STACKING              4
# LENGTH MANIPULATION         3
# QUERY FLOODING              3
# BASELINE REPLAY             2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-7_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    130578
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 130558
# LENGTH MANIPULATION         7
# QUERY FLOODING              4
# DELAY RESPONSE              3
# FRAME STACKING              2
# PAYLOAD INJECTION           2
# BASELINE REPLAY             2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    130615
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN               130596
# DELAY RESPONSE            5
# FRAME STACKING            5
# QUERY FLOODING            5
# PAYLOAD INJECTION         3
# BASELINE REPLAY           1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-14_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127727
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127713
# PAYLOAD INJECTION           4
# LENGTH MANIPULATION         3
# QUERY FLOODING              3
# BASELINE REPLAY             2
# DELAY RESPONSE              1
# FRAME STACKING              1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-17_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    131322
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 131305
# PAYLOAD INJECTION           5
# FRAME STACKING              3
# BASELINE REPLAY             3
# QUERY FLOODING              2
# DELAY RESPONSE              2
# LENGTH MANIPULATION         2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-6_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    129525
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 129504
# BASELINE REPLAY             6
# LENGTH MANIPULATION         4
# QUERY FLOODING              4
# PAYLOAD INJECTION           3
# DELAY RESPONSE              3
# FRAME STACKING              1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-11_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    126127
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126108
# PAYLOAD INJECTION           5
# FRAME STACKING              4
# BASELINE REPLAY             4
# LENGTH MANIPULATION         3
# DELAY RESPONSE              3
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-16_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    124626
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 124605
# PAYLOAD INJECTION           6
# QUERY FLOODING              5
# DELAY RESPONSE              4
# LENGTH MANIPULATION         2
# FRAME STACKING              2
# BASELINE REPLAY             2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-8_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    126633
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 126615
# PAYLOAD INJECTION           5
# FRAME STACKING              4
# QUERY FLOODING              3
# LENGTH MANIPULATION         3
# BASELINE REPLAY             3
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    128539
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 128521
# PAYLOAD INJECTION           6
# LENGTH MANIPULATION         4
# FRAME STACKING              4
# QUERY FLOODING              3
# BASELINE REPLAY             1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-15_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    128025
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 128006
# LENGTH MANIPULATION         4
# PAYLOAD INJECTION           4
# DELAY RESPONSE              3
# BASELINE REPLAY             3
# QUERY FLOODING              3
# FRAME STACKING              2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127125
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127108
# QUERY FLOODING              6
# PAYLOAD INJECTION           5
# FRAME STACKING              4
# DELAY RESPONSE              1
# LENGTH MANIPULATION         1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127488
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 127470
# PAYLOAD INJECTION           4
# DELAY RESPONSE              3
# QUERY FLOODING              3
# LENGTH MANIPULATION         3
# FRAME STACKING              3
# BASELINE REPLAY             2
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    127211
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN               127195
# BASELINE REPLAY          11
# PAYLOAD INJECTION         2
# QUERY FLOODING            2
# DELAY RESPONSE            1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    122560
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN             122548
# BASELINE REPLAY        12
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/trust-scada-hmi/trust-scada-network-captures/output/veth3efd353-10_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    125085
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN                 125066
# QUERY FLOODING              5
# PAYLOAD INJECTION           5
# BASELINE REPLAY             4
# LENGTH MANIPULATION         2
# DELAY RESPONSE              2
# FRAME STACKING              1
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    2836
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    2836
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    2306
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    2306
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    2564
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    2564
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    2857
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    2857
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/central-agent/central-agent-network-captures/output/vethffb308b-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    2614
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    2614
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-1_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    174978
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    174978
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-4_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    175803
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    175803
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-5_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    73647
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    73647
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-0_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    174255
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    174255
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-3_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    173532
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    173532
# Name: count, dtype: int64
# Attack directory ------------------------------ ./ModbusDataset/attack/compromised-ied/ied1a/ied1a-network-captures/output/veth3614724-2_fix_ord.pcap_Flow.csv
# labels after pre-processing:
#  Label
# NeedManualLabel    174892
# Name: count, dtype: int64
# label count after labelling:
#  Label
# BENIGN    174892
# Name: count, dtype: int64

# %%
string_types = [item[3] for item in attack_pairs]
from collections import Counter
type_counts = Counter(string_types)

print(type_counts)

print(f"Count for 'BRUTE FORCE': {type_counts['BRUTE FORCE']}")
# Out:
# Counter({'PAYLOAD INJECTION': 99, 'LENGTH MANIPULATION': 83, 'BASELINE REPLAY': 77, 'FRAME STACKING': 63, 'QUERY FLOODING': 62, 'DELAY RESPONSE': 50})
# Count for 'BRUTE FORCE': 0

# %% [markdown]
# #### Save the ready folders in a rar file for later uses.

# %%
def create_archive(archive_name, files_to_archive):
    with zipfile.ZipFile(archive_name, 'w') as zip_obj:
        for file in files_to_archive:
            if os.path.exists(file):
                zip_obj.write(file)
            else:
                print(f"Warning: File not found: {file}")

modbus_ready = ModbusDataset(root_dir,"ready")
files_to_archive  = modbus_ready.dataset["benign_dataset_dir"]
files_to_archive.extend(modbus_ready.dataset["attack_dataset_dir"]["total"])
dataset_total_number =modbus.dataset["metadata"]["founded_files_num"]["total_dataset_num"]
if len(files_to_archive)==dataset_total_number:
    print("all dataset csv files are labeled and ready to use!")
    archive_name = 'Labeled_CICMODBUS2023.zip'
    create_archive(archive_name, files_to_archive)
else:
    print(dataset_total_number-len(files_to_archive," files are not ready yet! "))
# Out:
# all dataset csv files are labeled and ready to use!
